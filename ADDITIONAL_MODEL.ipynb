# %% [markdown]
# # Emotion Recognition Training Notebook With Additional Model

# %%
from google.colab import drive
drive.mount('/content/drive')

from pathlib import Path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/codee/1-source-final
# Out:
# /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final

# %% [markdown]
# ## 1. RAF-DB

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shuvoalok/raf-db-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 37.7M/37.7M [00:00<00:00, 218MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/shuvoalok/raf-db-dataset/versions/2

# %% [markdown]
# ### 1.1 Baseline

# %%
# !python train.py --dataset rafdb --datapath "{path}" --batch_size 64 --modeltype large --epochs 1 --gpu 0 --baseline --save_dir checkpoint-save/additional_model --save_prefix rafdb_baseline
# Out:
# Work on GPU:  0
# Using RAF-DB path: /kaggle/input/raf-db-dataset/DATASET
# load_weight 304
# Train set size: 12271
# Validation set size: 3068
# batch_size: 64
# Total Parameters: 44.122M
# [Epoch 1/1][Train 1/192] loss: 6.4085 acc: 0.0156 lr: 0.000040
# [Epoch 1/1][Train 2/192] loss: 6.2716 acc: 0.0625 lr: 0.000040
# [Epoch 1/1][Train 3/192] loss: 5.8502 acc: 0.1823 lr: 0.000040
# [Epoch 1/1][Train 4/192] loss: 5.5593 acc: 0.2539 lr: 0.000040
# [Epoch 1/1][Train 5/192] loss: 5.5527 acc: 0.2625 lr: 0.000040
# [Epoch 1/1][Train 6/192] loss: 5.4421 acc: 0.3073 lr: 0.000040
# [Epoch 1/1][Train 7/192] loss: 5.4313 acc: 0.3237 lr: 0.000040
# [Epoch 1/1][Train 8/192] loss: 5.4112 acc: 0.3301 lr: 0.000040
# [Epoch 1/1][Train 9/192] loss: 5.3599 acc: 0.3472 lr: 0.000040
# [Epoch 1/1][Train 10/192] loss: 5.2967 acc: 0.3563 lr: 0.000040
# [Epoch 1/1][Train 11/192] loss: 5.2588 acc: 0.3523 lr: 0.000040
# [Epoch 1/1][Train 12/192] loss: 5.2409 acc: 0.3685 lr: 0.000040
# ...

# %%
# !python test.py --dataset rafdb --datapath "{path}" --checkpoint checkpoint-save/additional_model/rafdb_baseline_best.pth --gpu 0 -p --baseline
# Out:
# Work on GPU:  0
# Using RAF-DB path: /kaggle/input/raf-db-dataset/DATASET
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/rafdb_baseline_best.pth
# load_weight 691
# Test set size: 3068
# Test accuracy: 0.8598.
# Saving confusion matrix to: /content/drive/MyDrive/POSTER/Confusion_matrix/RAF-DB/acc0.8598.png
# Figure(640x480)

# %% [markdown]
# ### 1.2 ResNet

# %%
# !python train_resnet.py --dataset rafdb --datapath "{path}" --batch_size 64 --epochs 1 --workers 0 --log_every 1 --gpu 0 --save_dir checkpoint-save/additional_model --save_prefix rafdb_resnet18_b
# Out:
# Work on GPU: 0
# Using dataset: rafdb
# Train set size: 12271
# Validation set size: 3068
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 114MB/s]
# [Epoch 1/1][Train 1/192] loss: 2.0296 acc: 0.2969 lr: 0.000300
# [Epoch 1/1][Train 2/192] loss: 2.0031 acc: 0.2656 lr: 0.000300
# [Epoch 1/1][Train 3/192] loss: 1.9129 acc: 0.3073 lr: 0.000300
# [Epoch 1/1][Train 4/192] loss: 1.8603 acc: 0.3203 lr: 0.000300
# [Epoch 1/1][Train 5/192] loss: 1.7959 acc: 0.3344 lr: 0.000300
# [Epoch 1/1][Train 6/192] loss: 1.7430 acc: 0.3516 lr: 0.000300
# [Epoch 1/1][Train 7/192] loss: 1.7144 acc: 0.3683 lr: 0.000300
# [Epoch 1/1][Train 8/192] loss: 1.7004 acc: 0.3789 lr: 0.000300
# [Epoch 1/1][Train 9/192] loss: 1.6745 acc: 0.3941 lr: 0.000300
# [Epoch 1/1][Train 10/192] loss: 1.6266 acc: 0.4141 lr: 0.000300
# [Epoch 1/1][Train 11/192] loss: 1.5873 acc: 0.4304 lr: 0.000300
# ...

# %%
# !python test_resnet.py --dataset rafdb --datapath "{path}" -c checkpoint-save/additional_model/rafdb_resnet18_b_best.pth --workers 0 --gpu 0 -p
# Out:
# Work on GPU: 0
# Using dataset: rafdb
# Classes: ['1', '2', '3', '4', '5', '6', '7']
# Test set size: 3068
# Loading checkpoint... checkpoint-save/additional_model/rafdb_resnet18_b_best.pth
# Test accuracy: 0.7575.
# Saving confusion matrix to: /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/Confusion_matrix/RAF-DB_ResNet18/acc0.7575.png
# Figure(640x480)

# %% [markdown]
# ## 2. AffectNet 7 Classes

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lcdngthnh/affectnet-7")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'affectnet-7' dataset.
# Path to dataset files: /kaggle/input/affectnet-7

# %%
path = Path(path) / 'AffectNet'

# %% [markdown]
# ### 2.1 Baseline

# %%
# !python train_affect.py --dataset affectnet --datapath "{path}" --batch_size 64 --modeltype large --epochs 1 --gpu 0 --baseline --save_dir checkpoint-save/additional_model --save_prefix affectnet7_baseline
# Out:
# Work on GPU:  0
# load_weight 304
# Train set size: 14549
# Validation set size: 13206
# batch_size: 64
# Total Parameters: 44.122M
# [Epoch 1/1][Train 1/228] loss: 6.1585 acc: 0.2031 lr: 0.000040
# [Epoch 1/1][Train 2/228] loss: 5.9070 acc: 0.2031 lr: 0.000040
# [Epoch 1/1][Train 3/228] loss: 5.8231 acc: 0.2135 lr: 0.000040
# [Epoch 1/1][Train 4/228] loss: 5.7713 acc: 0.2148 lr: 0.000040
# [Epoch 1/1][Train 5/228] loss: 5.7278 acc: 0.2438 lr: 0.000040
# [Epoch 1/1][Train 6/228] loss: 5.6607 acc: 0.2578 lr: 0.000040
# [Epoch 1/1][Train 7/228] loss: 5.6108 acc: 0.2902 lr: 0.000040
# [Epoch 1/1][Train 8/228] loss: 5.4882 acc: 0.3262 lr: 0.000040
# [Epoch 1/1][Train 9/228] loss: 5.4168 acc: 0.3385 lr: 0.000040
# [Epoch 1/1][Train 10/228] loss: 5.3323 acc: 0.3422 lr: 0.000040
# [Epoch 1/1][Train 11/228] loss: 5.2696 acc: 0.3466 lr: 0.000040
# [Epoch 1/1][Train 12/228] loss: 5.2380 acc: 0.3477 lr: 0.000040
# [Epoch 1/1][Train 13/228] loss: 5.1845 acc: 0.3606 lr: 0.000040
# ...

# %%
# !python test_affect.py --dataset affectnet --datapath "{path}" -c checkpoint-save/additional_model/affectnet7_baseline_best.pth --gpu 0 -p --baseline
# Out:
# Work on GPU:  0
# Using AffectNet7 path: /root/.cache/kagglehub/datasets/lcdngthnh/affectnet-7/versions/1/AffectNet
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/affectnet7_baseline_best.pth
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/test_affect.py", line 173, in <module>
#     test()
#   File "/content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/test_affect.py", line 115, in test
#     checkpoint = torch.load(args.checkpoint, weights_only=False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1500, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 768, in _open_file_like
# ...

# %% [markdown]
# ### 2.2 ResNet

# %%
# !python train_resnet.py --dataset affectnet --datapath "{path}" --batch_size 64 --epochs 1 --gpu 0 --save_dir checkpoint-save/additional_model --save_prefix affectnet7_resnet18_b_best
# Out:
# Work on GPU: 0
# Using dataset: affectnet
# Train set size: 14549
# Validation set size: 13206
# [Epoch 1/1][Train 20/228] loss: 1.4009 acc: 0.4602 lr: 0.000300
# [Epoch 1/1][Train 40/228] loss: 1.2321 acc: 0.5203 lr: 0.000300
# [Epoch 1/1][Train 60/228] loss: 1.1609 acc: 0.5497 lr: 0.000300
# [Epoch 1/1][Train 80/228] loss: 1.1173 acc: 0.5637 lr: 0.000300
# [Epoch 1/1][Train 100/228] loss: 1.0728 acc: 0.5819 lr: 0.000300
# [Epoch 1/1][Train 120/228] loss: 1.0424 acc: 0.5947 lr: 0.000300
# [Epoch 1/1][Train 140/228] loss: 1.0268 acc: 0.6018 lr: 0.000300
# [Epoch 1/1][Train 160/228] loss: 1.0141 acc: 0.6048 lr: 0.000300
# [Epoch 1/1][Train 180/228] loss: 0.9977 acc: 0.6121 lr: 0.000300
# [Epoch 1/1][Train 200/228] loss: 0.9789 acc: 0.6206 lr: 0.000300
# [Epoch 1/1][Train 220/228] loss: 0.9670 acc: 0.6249 lr: 0.000300
# [Epoch 1/1][Train 228/228] loss: 0.9607 acc: 0.6269 lr: 0.000300
# [Epoch 1] Train time: 0.72 min, Training accuracy: 0.6269, Loss: 0.9607
# ...

# %%
# !ls /content/drive/MyDrive/codee/
# Out:
# 1-source-final			affectnet7_resnet18_b_best_latest.pth
# affectnet7_baseline_latest.pth

# %%
# !python test_resnet.py --dataset affectnet --datapath "{path}" -c "/content/drive/MyDrive/codee/affectnet7_resnet18_b_best_latest.pth" --gpu 0 -p
# Out:
# Work on GPU: 0
# Using dataset: affectnet
# Classes: ['neutral', 'happy', 'sad', 'surprise', 'fear', 'disgust', 'anger']
# Test set size: 13206
# Loading checkpoint... /content/drive/MyDrive/codee/affectnet7_resnet18_b_best_latest.pth
# Test accuracy: 0.6684.
# Saving confusion matrix to: /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/Confusion_matrix/AffectNet7_ResNet18/acc0.6684.png
# Figure(640x480)

# %% [markdown]
# ## 3. AffectNet 8 Classes

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mstjebashazida/affectnet")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'affectnet' dataset.
# Path to dataset files: /kaggle/input/affectnet

# %%
path = Path(path) / 'archive (3)'

# %%
# !ls "{path}"
# Out:
# labels.csv  Test  Train

# %% [markdown]
# ### 3.1 Baseline

# %%
# !python train_affect.py --dataset affectnet8class --datapath "{path}" --batch_size 64 --modeltype large --epochs 1 --gpu 0 --baseline --save_dir checkpoint-save/additional_model --save_prefix affectnet8_baseline
# Out:
# Work on GPU:  0
# Using AffectNet8 path: /kaggle/input/affectnet/archive (3)
# load_weight 304
# Train set size: 16108
# Validation set size: 14518
# batch_size: 64
# Total Parameters: 44.123M
# [Epoch 1/1][Train 1/252] loss: 6.9529 acc: 0.1094 lr: 0.000040
# [Epoch 1/1][Train 2/252] loss: 6.7332 acc: 0.1172 lr: 0.000040
# [Epoch 1/1][Train 3/252] loss: 6.4511 acc: 0.1875 lr: 0.000040
# [Epoch 1/1][Train 4/252] loss: 6.2637 acc: 0.2305 lr: 0.000040
# [Epoch 1/1][Train 5/252] loss: 6.1823 acc: 0.2688 lr: 0.000040
# [Epoch 1/1][Train 6/252] loss: 6.2038 acc: 0.2656 lr: 0.000040
# [Epoch 1/1][Train 7/252] loss: 6.1249 acc: 0.2835 lr: 0.000040
# [Epoch 1/1][Train 8/252] loss: 6.0177 acc: 0.2988 lr: 0.000040
# [Epoch 1/1][Train 9/252] loss: 5.8820 acc: 0.3108 lr: 0.000040
# [Epoch 1/1][Train 10/252] loss: 5.7909 acc: 0.3250 lr: 0.000040
# [Epoch 1/1][Train 11/252] loss: 5.7120 acc: 0.3366 lr: 0.000040
# [Epoch 1/1][Train 12/252] loss: 5.6498 acc: 0.3464 lr: 0.000040
# ...

# %%
# !python test_affect.py --dataset affectnet8class --datapath "{path}" -c checkpoint-save/additional_model/affectnet8_baseline_best.pth --gpu 0 -p --baseline
# Out:
# Work on GPU:  0
# Using AffectNet8 path: /kaggle/input/affectnet/archive (3)
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/affectnet8_baseline_best.pth
# load_weight 691
# Test set size: 14518
# Test accuracy: 0.6681.
# Saving confusion matrix to: /content/drive/MyDrive/POSTER/Confusion_matrix/AffectNet_8class/acc0.6681.png
# Figure(640x480)

# %% [markdown]
# ### 3.2 ResNet

# %%
# !python train_resnet.py --dataset affectnet8class --datapath "{path}" --batch_size 64 --epochs 1 --gpu 0 --save_dir checkpoint-save/additional_model --save_prefix affectnet8_resnet18_b
# Out:
# Work on GPU: 0
# Using dataset: affectnet8class
# Train set size: 16108
# Validation set size: 14518
# [Epoch 1/1][Train 20/252] loss: 1.5365 acc: 0.4055 lr: 0.000300
# [Epoch 1/1][Train 40/252] loss: 1.3605 acc: 0.4711 lr: 0.000300
# [Epoch 1/1][Train 60/252] loss: 1.2704 acc: 0.5076 lr: 0.000300
# [Epoch 1/1][Train 80/252] loss: 1.2215 acc: 0.5311 lr: 0.000300
# [Epoch 1/1][Train 100/252] loss: 1.1795 acc: 0.5483 lr: 0.000300
# [Epoch 1/1][Train 120/252] loss: 1.1448 acc: 0.5615 lr: 0.000300
# [Epoch 1/1][Train 140/252] loss: 1.1254 acc: 0.5698 lr: 0.000300
# [Epoch 1/1][Train 160/252] loss: 1.0997 acc: 0.5824 lr: 0.000300
# [Epoch 1/1][Train 180/252] loss: 1.0770 acc: 0.5906 lr: 0.000300
# [Epoch 1/1][Train 200/252] loss: 1.0652 acc: 0.5949 lr: 0.000300
# [Epoch 1/1][Train 220/252] loss: 1.0553 acc: 0.5991 lr: 0.000300
# [Epoch 1/1][Train 240/252] loss: 1.0441 acc: 0.6044 lr: 0.000300
# [Epoch 1/1][Train 252/252] loss: 1.0352 acc: 0.6084 lr: 0.000300
# ...

# %%
# !python test_resnet.py --dataset affectnet8class --datapath "{path}" -c checkpoint-save/additional_model/affectnet8_resnet18_b_best.pth --gpu 0 -p
# Out:
# Work on GPU: 0
# Using dataset: affectnet8class
# Classes: ['neutral', 'happy', 'sad', 'surprise', 'fear', 'disgust', 'anger', 'contempt']
# Test set size: 14518
# Loading checkpoint... checkpoint-save/additional_model/affectnet8_resnet18_b_best.pth
# Test accuracy: 0.6292.
# Saving confusion matrix to: /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/Confusion_matrix/AffectNet8_ResNet18/acc0.6292.png
# Figure(640x480)

# %% [markdown]
# ## 4. FERPlus

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arnabkumarroy02/ferplus")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 487M/487M [00:06<00:00, 82.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/arnabkumarroy02/ferplus/versions/3

# %% [markdown]
# ### 4.1 Baseline

# %%
# !python train.py --dataset ferplus --datapath "{path}" --batch_size 64 --modeltype large --epochs 1 --gpu 0 --baseline --save_dir checkpoint-save/additional_model --save_prefix ferplus_baseline
# Out:
# Work on GPU:  0
# FERPlus dataset: mode=train, loaded 66379 images
# FERPlus dataset: mode=test, loaded 3573 images
# load_weight 304
# Train set size: 66379
# Validation set size: 3573
# batch_size: 64
# Total Parameters: 44.123M
# [Epoch 1/1][Train 1/1038] loss: 6.8262 acc: 0.1094 lr: 0.000040
# [Epoch 1/1][Train 2/1038] loss: 6.5762 acc: 0.1016 lr: 0.000040
# [Epoch 1/1][Train 3/1038] loss: 6.5442 acc: 0.0990 lr: 0.000040
# [Epoch 1/1][Train 4/1038] loss: 6.5337 acc: 0.0977 lr: 0.000040
# [Epoch 1/1][Train 5/1038] loss: 6.5115 acc: 0.1063 lr: 0.000040
# [Epoch 1/1][Train 6/1038] loss: 6.5262 acc: 0.1146 lr: 0.000040
# [Epoch 1/1][Train 7/1038] loss: 6.4883 acc: 0.1317 lr: 0.000040
# [Epoch 1/1][Train 8/1038] loss: 6.4327 acc: 0.1445 lr: 0.000040
# [Epoch 1/1][Train 9/1038] loss: 6.3908 acc: 0.1580 lr: 0.000040
# [Epoch 1/1][Train 10/1038] loss: 6.3619 acc: 0.1547 lr: 0.000040
# [Epoch 1/1][Train 11/1038] loss: 6.3062 acc: 0.1634 lr: 0.000040
# ...

# %%
# !python test.py --dataset ferplus --datapath "{path}" --checkpoint checkpoint-save/additional_model/ferplus_baseline_latest.pth --gpu 0 -p --baseline
# Out:
# Work on GPU:  0
# FERPlus dataset: mode=test, loaded 3573 images
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/ferplus_baseline_latest.pth
# load_weight 691
# Test set size: 3573
# Test accuracy: 0.8083.
# Saving confusion matrix to: /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/Confusion_matrix/FERPlus/acc0.8083.png
# Figure(640x480)

# %% [markdown]
# ### 4.2 ResNet

# %%
# !python train_resnet.py --dataset ferplus --datapath "{path}" --batch_size 64 --epochs 1 --gpu 0 --save_dir checkpoint-save/additional_model --save_prefix ferplus_resnet18_b
# Out:
# Work on GPU: 0
# FERPlus dataset: mode=train, loaded 66379 images
# FERPlus dataset: mode=test, loaded 3573 images
# Using dataset: ferplus
# Train set size: 66379
# Validation set size: 3573
# [Epoch 1/1][Train 20/1038] loss: 1.6563 acc: 0.3750 lr: 0.000300
# [Epoch 1/1][Train 40/1038] loss: 1.4918 acc: 0.4504 lr: 0.000300
# [Epoch 1/1][Train 60/1038] loss: 1.3557 acc: 0.5073 lr: 0.000300
# [Epoch 1/1][Train 80/1038] loss: 1.2606 acc: 0.5426 lr: 0.000300
# [Epoch 1/1][Train 100/1038] loss: 1.1829 acc: 0.5745 lr: 0.000300
# [Epoch 1/1][Train 120/1038] loss: 1.1358 acc: 0.5926 lr: 0.000300
# [Epoch 1/1][Train 140/1038] loss: 1.0866 acc: 0.6105 lr: 0.000300
# [Epoch 1/1][Train 160/1038] loss: 1.0536 acc: 0.6211 lr: 0.000300
# [Epoch 1/1][Train 180/1038] loss: 1.0181 acc: 0.6345 lr: 0.000300
# [Epoch 1/1][Train 200/1038] loss: 0.9878 acc: 0.6447 lr: 0.000300
# [Epoch 1/1][Train 220/1038] loss: 0.9588 acc: 0.6565 lr: 0.000300
# ...

# %%
# !python test_resnet.py --dataset ferplus --datapath "{path}" -c checkpoint-save/additional_model/ferplus_resnet18_b_best.pth --gpu 0 -p
# Out:
# Work on GPU: 0
# FERPlus dataset: mode=test, loaded 3573 images
# Using dataset: ferplus
# Classes: ['neutral', 'happy', 'surprise', 'sad', 'anger', 'disgust', 'fear', 'contempt']
# Test set size: 3573
# Loading checkpoint... checkpoint-save/additional_model/ferplus_resnet18_b_best.pth
# Test accuracy: 0.7674.
# Saving confusion matrix to: /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/Confusion_matrix/FERPlus_ResNet18/acc0.7674.png
# Figure(640x480)

# %% [markdown]
# ## 5. SFEW

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dollyprajapati182/balanced-sfew-dataset-7575-grayscale")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 107MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dollyprajapati182/balanced-sfew-dataset-7575-grayscale/versions/1

# %%
# !ls /root/.cache/kagglehub/datasets/dollyprajapati182/balanced-sfew-dataset-7575-grayscale/versions/1

# %% [markdown]
# ### 5.1 Baseline

# %%
# !python trainsfew.py --datapath "{path}" --batch_size 64 --modeltype large --epochs 5 --gpu 0 --baseline --save_dir checkpoint-save/additional_model --save_prefix sfew_baseline
# Out:
# Work on GPU: 0
# Using SFEW path: /root/.cache/kagglehub/datasets/dollyprajapati182/balanced-sfew-dataset-7575-grayscale/versions/1
# Classes: ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
# Train set size: 1288
# Validation set size: 322
# load_weight 304
# Total Parameters: 44.122M
# [Epoch 1/5][Train 10/21] loss: 5.9288 acc: 0.1781 lr: 0.000040
# [Epoch 1/5][Train 20/21] loss: 5.7515 acc: 0.2156 lr: 0.000040
# [Epoch 1/5][Train 21/21] loss: 5.7271 acc: 0.2166 lr: 0.000040
# [Epoch 1] Train time: 0.20 min, Training accuracy: 0.2166, Loss: 5.7271, LR: 0.000040
# [Epoch 1/5][Val 6/6] loss: 1.7624
# [Epoch 1] Validation accuracy: 0.4068, Loss: 1.7624, f1: 0.3437, score: 0.3645
# Saved latest checkpoint to checkpoint-save/additional_model/sfew_baseline_latest.pth
# Saved best checkpoint to checkpoint-save/additional_model/sfew_baseline_best.pth
# best_acc: 0.40683229813664595
# [Epoch 2/5][Train 10/21] loss: 4.7483 acc: 0.4750 lr: 0.000039
# ...

# %%
# !python testsfew.py --datapath "{path}" -c checkpoint-save/additional_model/sfew_baseline_best.pth --gpu 0 -p --baseline
# Out:
# Work on GPU: 0
# Using SFEW path: /root/.cache/kagglehub/datasets/dollyprajapati182/balanced-sfew-dataset-7575-grayscale/versions/1
# Classes: ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
# Test set size: 182
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/sfew_baseline_best.pth
# load_weight 691
# Test accuracy: 0.7253.
# Saving confusion matrix to: /content/drive/MyDrive/POSTER/Confusion_matrix/SFEW/acc0.7253.png
# Figure(640x480)

# %% [markdown]
# ### 5.2 ResNet

# %%
# !python train_resnet.py --dataset sfew --datapath "{path}" --batch_size 64 --epochs 5 --gpu 0 --save_dir checkpoint-save/additional_model --save_prefix sfew_resnet18_b
# Out:
# Work on GPU: 0
# Using dataset: sfew
# Train set size: 1288
# Validation set size: 322
# [Epoch 1/5][Train 20/21] loss: 1.7152 acc: 0.3414 lr: 0.000300
# [Epoch 1/5][Train 21/21] loss: 1.6928 acc: 0.3424 lr: 0.000300
# [Epoch 1] Train time: 0.07 min, Training accuracy: 0.3424, Loss: 1.6928
# [Epoch 1] Validation accuracy:0.3416. Loss:1.595, F1:0.3325
# Saving best checkpoint to checkpoint-save/additional_model/sfew_resnet18_b_best.pth
# [Epoch 2/5][Train 20/21] loss: 1.0922 acc: 0.6336 lr: 0.000271
# [Epoch 2/5][Train 21/21] loss: 1.0756 acc: 0.6351 lr: 0.000271
# [Epoch 2] Train time: 0.07 min, Training accuracy: 0.6351, Loss: 1.0756
# [Epoch 2] Validation accuracy:0.5280. Loss:1.293, F1:0.5320
# Saving best checkpoint to checkpoint-save/additional_model/sfew_resnet18_b_best.pth
# [Epoch 3/5][Train 20/21] loss: 0.6506 acc: 0.8016 lr: 0.000196
# [Epoch 3/5][Train 21/21] loss: 0.6676 acc: 0.8012 lr: 0.000196
# [Epoch 3] Train time: 0.05 min, Training accuracy: 0.8012, Loss: 0.6676
# ...

# %%
# !python test_resnet.py --dataset sfew --datapath "{path}" -c checkpoint-save/additional_model/sfew_resnet18_b_best.pth --gpu 0 -p
# Out:
# Work on GPU: 0
# Using dataset: sfew
# Classes: ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
# Test set size: 182
# Loading checkpoint... checkpoint-save/additional_model/sfew_resnet18_b_best.pth
# Test accuracy: 0.7198.
# Saving confusion matrix to: /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/Confusion_matrix/SFEW_ResNet18/acc0.7198.png
# Figure(640x480)

# %% [markdown]
# ### 5.3 Poster

# %%
# !python trainsfew.py --datapath "{path}" --batch_size 64 --modeltype large --epochs 5 --gpu 0 --poster --save_dir checkpoint-save/additional_model --save_prefix sfew_poster
# Out:
# Work on GPU: 0
# Using SFEW path: /root/.cache/kagglehub/datasets/dollyprajapati182/balanced-sfew-dataset-7575-grayscale/versions/1
# Classes: ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
# Train set size: 1288
# Validation set size: 322
# load_weight 304
# Total Parameters: 70.843M
# [Epoch 1/5][Train 10/21] loss: 5.8384 acc: 0.2234 lr: 0.000040
# [Epoch 1/5][Train 20/21] loss: 5.6072 acc: 0.2820 lr: 0.000040
# [Epoch 1/5][Train 21/21] loss: 5.5855 acc: 0.2826 lr: 0.000040
# [Epoch 1] Train time: 0.27 min, Training accuracy: 0.2826, Loss: 5.5855, LR: 0.000040
# [Epoch 1/5][Val 6/6] loss: 1.6522
# [Epoch 1] Validation accuracy: 0.4410, Loss: 1.6522, f1: 0.4193, score: 0.4265
# Saved latest checkpoint to checkpoint-save/additional_model/sfew_poster_latest.pth
# Saved best checkpoint to checkpoint-save/additional_model/sfew_poster_best.pth
# best_acc: 0.4409937888198758
# [Epoch 2/5][Train 10/21] loss: 4.3744 acc: 0.5719 lr: 0.000039
# ...

# %%
# !python testsfew.py --datapath "{path}" -c checkpoint-save/additional_model/sfew_poster_best.pth --gpu 0 -p --poster
# Out:
# Work on GPU: 0
# Using SFEW path: /root/.cache/kagglehub/datasets/dollyprajapati182/balanced-sfew-dataset-7575-grayscale/versions/1
# Classes: ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
# Test set size: 182
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/sfew_poster_best.pth
# load_weight 1309
# Test accuracy: 0.7088.
# Saving confusion matrix to: /content/drive/MyDrive/POSTER/Confusion_matrix/SFEW/acc0.7088.png
# Figure(640x480)

# %% [markdown]
# ## 6. Fer2013

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("msambare/fer2013")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.
# Path to dataset files: /kaggle/input/fer2013

# %%
# !ls /root/.cache/kagglehub/datasets/msambare/fer2013/versions/1

# %% [markdown]
# ### 6.1 Baseline

# %%
# !python trainfer2013.py --datapath "{path}" --batch_size 128 --modeltype large --epochs 1 --gpu 0 --baseline --save_dir checkpoint-save/additional_model --save_prefix fer2013_baseline
# Out:
# Work on GPU: 0
# Using FER2013 path: /kaggle/input/fer2013
# Classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Train set size: 28709
# Validation set size (using test split): 7178
# load_weight 304
# Total Parameters: 44.122M
# [Epoch 1/1][Train 20/225] loss: 5.3175 acc: 0.3203 lr: 0.000040
# [Epoch 1/1][Train 40/225] loss: 4.8099 acc: 0.4252 lr: 0.000040
# [Epoch 1/1][Train 60/225] loss: 4.5075 acc: 0.4861 lr: 0.000040
# [Epoch 1/1][Train 80/225] loss: 4.3335 acc: 0.5225 lr: 0.000040
# [Epoch 1/1][Train 100/225] loss: 4.2302 acc: 0.5427 lr: 0.000040
# [Epoch 1/1][Train 120/225] loss: 4.1471 acc: 0.5587 lr: 0.000040
# [Epoch 1/1][Train 140/225] loss: 4.0834 acc: 0.5706 lr: 0.000040
# [Epoch 1/1][Train 160/225] loss: 4.0373 acc: 0.5792 lr: 0.000040
# [Epoch 1/1][Train 180/225] loss: 3.9916 acc: 0.5875 lr: 0.000040
# [Epoch 1/1][Train 200/225] loss: 3.9522 acc: 0.5948 lr: 0.000040
# [Epoch 1/1][Train 220/225] loss: 3.9190 acc: 0.6018 lr: 0.000040
# ...

# %%
# !python testfer2013.py --datapath "{path}" -c checkpoint-save/additional_model/fer2013_baseline_best.pth --gpu 0 -p --baseline
# Out:
# Work on GPU: 0
# Using FER2013 path: /kaggle/input/fer2013
# Classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Test set size: 7178
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/fer2013_baseline_best.pth
# load_weight 691
# Test accuracy: 0.6590.
# Saving confusion matrix to: /content/drive/MyDrive/POSTER/Confusion_matrix/FER2013/acc0.659.png
# Figure(640x480)

# %% [markdown]
# ### 6.2 ResNet

# %%
# !python train_resnet.py --dataset fer2013 --datapath "{path}" --batch_size 128 --epochs 1 --gpu 0 --save_dir checkpoint-save/additional_model --save_prefix fer2013_resnet18_b
# Out:
# Work on GPU: 0
# Using dataset: fer2013
# Train set size: 28709
# Validation set size: 7178
# [Epoch 1/1][Train 20/225] loss: 1.6344 acc: 0.3680 lr: 0.000300
# [Epoch 1/1][Train 40/225] loss: 1.4743 acc: 0.4352 lr: 0.000300
# [Epoch 1/1][Train 60/225] loss: 1.3894 acc: 0.4665 lr: 0.000300
# [Epoch 1/1][Train 80/225] loss: 1.3289 acc: 0.4932 lr: 0.000300
# [Epoch 1/1][Train 100/225] loss: 1.2862 acc: 0.5081 lr: 0.000300
# [Epoch 1/1][Train 120/225] loss: 1.2509 acc: 0.5220 lr: 0.000300
# [Epoch 1/1][Train 140/225] loss: 1.2249 acc: 0.5315 lr: 0.000300
# [Epoch 1/1][Train 160/225] loss: 1.2063 acc: 0.5407 lr: 0.000300
# [Epoch 1/1][Train 180/225] loss: 1.1914 acc: 0.5478 lr: 0.000300
# [Epoch 1/1][Train 200/225] loss: 1.1764 acc: 0.5532 lr: 0.000300
# [Epoch 1/1][Train 220/225] loss: 1.1621 acc: 0.5588 lr: 0.000300
# [Epoch 1/1][Train 225/225] loss: 1.1589 acc: 0.5595 lr: 0.000300
# [Epoch 1] Train time: 1.91 min, Training accuracy: 0.5595, Loss: 1.1589
# ...

# %%
# !python test_resnet.py --dataset fer2013 --datapath "{path}" -c checkpoint-save/additional_model/fer2013_resnet18_b_best.pth --gpu 0 -p
# Out:
# Work on GPU: 0
# Using dataset: fer2013
# Classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Test set size: 7178
# Loading checkpoint... checkpoint-save/additional_model/fer2013_resnet18_b_best.pth
# Test accuracy: 0.5991.
# Saving confusion matrix to: /content/drive/.shortcut-targets-by-id/1dHP1zaCyRhJudTFBZ_ivw48q0waIdsjx/1-source-final/Confusion_matrix/FER2013_ResNet18/acc0.5991.png
# Figure(640x480)

# %% [markdown]
# ### 6.2 Poster

# %%
# !python trainfer2013.py --datapath "{path}" --batch_size 128 --modeltype large --epochs 1 --gpu 0 --poster --save_dir checkpoint-save/additional_model --save_prefix fer2013_poster
# Out:
# Work on GPU: 0
# Using FER2013 path: /kaggle/input/fer2013
# Classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Train set size: 28709
# Validation set size (using test split): 7178
# load_weight 304
# Total Parameters: 70.843M
# [Epoch 1/1][Train 20/225] loss: 5.1413 acc: 0.3672 lr: 0.000040
# [Epoch 1/1][Train 40/225] loss: 4.6909 acc: 0.4604 lr: 0.000040
# [Epoch 1/1][Train 60/225] loss: 4.4437 acc: 0.5064 lr: 0.000040
# [Epoch 1/1][Train 80/225] loss: 4.3084 acc: 0.5316 lr: 0.000040
# [Epoch 1/1][Train 100/225] loss: 4.2137 acc: 0.5476 lr: 0.000040
# [Epoch 1/1][Train 120/225] loss: 4.1235 acc: 0.5646 lr: 0.000040
# [Epoch 1/1][Train 140/225] loss: 4.0535 acc: 0.5771 lr: 0.000040
# [Epoch 1/1][Train 160/225] loss: 4.0065 acc: 0.5862 lr: 0.000040
# [Epoch 1/1][Train 180/225] loss: 3.9597 acc: 0.5944 lr: 0.000040
# [Epoch 1/1][Train 200/225] loss: 3.9173 acc: 0.6036 lr: 0.000040
# [Epoch 1/1][Train 220/225] loss: 3.8839 acc: 0.6096 lr: 0.000040
# ...

# %%
# !python testfer2013.py --datapath "{path}" -c checkpoint-save/additional_model/fer2013_poster_best.pth --gpu 0 -p --poster
# Out:
# Work on GPU: 0
# Using FER2013 path: /kaggle/input/fer2013
# Classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Test set size: 7178
# load_weight 304
# Loading pretrained weights... checkpoint-save/additional_model/fer2013_poster_best.pth
# load_weight 1309
# Test accuracy: 0.6544.
# Saving confusion matrix to: /content/drive/MyDrive/POSTER/Confusion_matrix/FER2013/acc0.6544.png
# Figure(640x480)
